# %%
age=25
print(age)
# Out:
# 25

# %%
A=10
a=20
print(A)
print(a)
# Out:
# 10
# 20

# %% [markdown]
# ## Rules for creating Identifiers

# %%
Age=20

# %%
_a=0

# %%
1a=4
# Out:
#   Cell In[8], line 1
#     1a=4
#     ^
# SyntaxError: invalid decimal literal

# %%
a1b2=34

# %%
def=2  #keyword never used as a indentifier
# Out:
#   Cell In[11], line 1
#     def=2
#        ^
# SyntaxError: invalid syntax

# %%
$age=25 #spl character never come first
# Out:
#   Cell In[12], line 1
#     $age=25
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Data types

# %%
age=25
print(type(age))

weight=51.50
print(type(weight))

complx=1+2j
print(type(complx))

name=("Gayatri")
print(type(name))

voting=True
print(type(voting))

is_Active=True
print(type(is_Active))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'bool'>
# <class 'bool'>

# %%
# Float Decimal

pi=3.14
print(type(pi))

pi_exp=3.14e2 # 3.14 * 10^2 
print(type(pi_exp))
print(pi_exp)
# Out:
# <class 'float'>
# <class 'float'>
# 314.0

# %%
name = "Gayatri"

name1= 'Gayatri'

name2= '''Gayatri'''

print(type(name))
print(type(name1))
print(type(name2))

name3= "!@#$%^&*()_+~"
print(type(name3))

age ,weight ,num ,eligible_for_voting = 10 ,65.6 ,1+2j ,True 
print(age,weight,num,eligible_for_voting)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# 10 65.6 (1+2j) True

# %%
# Out:
# My name is : Gayatri
