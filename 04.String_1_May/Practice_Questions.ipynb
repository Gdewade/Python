# %% [markdown]
# # 20 April

# %% [markdown]
# # String Basics

# %%
# 1.	Create a variable city and store your city name using double quotes. Print it and check its type.

city="Pune"
print(city)
print(type(city))
# Out:
# Pune
# <class 'str'>

# %%
#2.	Store the string "let's go" using single quotes with an escape character. Print it.

text='let\'s go'
print(text)
# Out:
# let's go

# %%
#3.	Create a multiline string using triple double quotes """ containing 3 lines about yourself (name, city, college). Print it.

text="""My name is Gayatri 
i am from pune
i completed my bsc cs from modern college,shivajinagar"""

print(text)
# Out:
# My name is Gayatri
# i am from pune
# i completed my bsc cs from modern college,shivajinagar

# %%
#4. Create the same multiline string using the backslash \ continuation method with single quotes. What difference do you notice in the output

text='My name is Gayatri\
i am from pune \
i completed my bsc cs from modern college,shivajinagar'

print(text)

# Difference is when we used *** they print the text into multiline and when we used \ they print the text into single line
# Out:
# My name is Gayatrii am from pune i completed my bsc cs from modern college,shivajinagar

# %% [markdown]
# # Indexing

# %%
#5.	str1 = "Python" — Print the first character, last character, and middle character using positive indexing.

str1="Python"

print(str1[0] + str1[3] + str1[5])
# Out:
# Phn

# %%
#6.	str1 = "Python" — Print the same characters using negative indexing.

str1="python"

print(str1[-6] + str1[-3] + str1[-1])
# Out:
# phn

# %%
#7.	str2 = "welcome to india" — What is str2[4]? What is str2[-4]? Write the code and verify.

str2 = "welcome to india"

print(str2[4])
print(str2[-4])
# Out:
# o
# n

# %%
#8.	str3 = "Hello World" — Print the character at index 6 using both positive and negative index.

str3 = "Hello World"

print(str3[6])  # w
print(str3[-6]) # " "
# Out:
# W

# %%
#9.	Given str4 = "DataScience", find which index gives you the letter S (both positive and negative).

str4 = "DataScience"

print(str4[4])
print(str4[-7])
# Out:
# S
# S

# %%
#10. str5 = "Rajesh" — Print each character one by one using its positive index (0 to 5).

str5 = "Rajesh"

print(str5[0])
print(str5[1])
print(str5[2])
print(str5[3])
print(str5[4])
print(str5[5])
# Out:
# R
# a
# j
# e
# s
# h

# %% [markdown]
# # Slicing

# %%
#11.	str6 = "welcome to india" — Slice and print only "welcome".

str6 = "welcome to india"
print(str6[0:7])
# Out:
# welcome

# %%
#12.	From the same string, slice and print only "india".

str6 = "welcome to india"
print(str6[11:16])
# Out:
# india

# %%
#13.	From str6 = "welcome to india", use a step of 2 to print every alternate character from index 0 to 7.

str6 = "welcome to india"
print(str6[0:7:2])
# Out:
# wloe

# %%
#14.	str7 = "Artificial Intelligence" — Slice "Intelligence" from this string.

str7 = "Artificial Intelligence"
print(str7[11:23])
# Out:
# Intelligence

# %%
#15.	From str7 = "Artificial Intelligence", print the entire string using [::], then again using [0:23:1]. Confirm the outputs match.

str7 = "Artificial Intelligence"

print(str7[::])
print(str7[0:23:1])
# Out:
# Artificial Intelligence
# Artificial Intelligence

# %% [markdown]
# # 21 April

# %%
# 1. Explain why strings are immutable in Python.

# Strings are immutable because we cant change or modify the string once it created , when we try to modify the same string again it will change the memory address

# for ex;

text="Gayatri"
print("Memory address before modification:",id(text))

# after modify it 

text="Gayatri Dewade"
print("Memory address after modification :",id(text))
# Out:
# Memory address before modification: 1588149279728
# Memory address after modification : 1588150518320

# %%
# 2. Write a program to access the first and last character of a string.

text="Gayatri"

print("Access first character : ",text[0])
print("Access last character : ",text[6])
# Out:
# Access first character :  G
# Access last character :  i

# %%
# 3. Write a program to extract a word from a sentence using slicing.

text="My name is Gayatri"

print("The word extract using slicing is : ",text[11:18])
# Out:
# The word extract using slicing is :  Gayatri

# %%
# 4. Write a program to join first name and last name using concatenation.

name="Gayatri"
surname="Dewade" 
fullname=name+" "+surname
print(fullname)
# Out:
# Gayatri Dewade

# %%
# 5. Write a program to repeat a string 4 times using the repetition operator.

text="Danger!!!"+" "
print(text * 3)
# Out:
# Danger!!! Danger!!! Danger!!!

# %%
# 6. Write a program to check whether a given substring exists inside another string.

substring="Gayatri"
substring2="Dewade"
text="My name is Gayatri"
print(substring in text)
print(substring2 not in text)
# Out:
# True
# True

# %%
# 7. Write a program to check whether a word is not present in a sentence.

word="Evening"
sentence= "Good Morning Everyone"
print(word not in sentence)
# Out:
# True

# %%
# 8. Write a program to find the length of a string using `len()`.

text="Hello world"
print(len(text))
# Out:
# 11

# %%
# 9. Write a program to find the minimum character in a string.

text="Hello"
print(min(text))
ord("H")
# Out:
# H
# 72

# %%
# 10. Write a program to find the maximum character in a string.

text="Hello"
print(max(text))
ord("H")
# Out:
# o
# 72

# %%
# 11. Write a program to print the ASCII value of a given character using `ord()`.

#text="G"
text=input("Enter the character : ")
print("ASCII value / Unicode value of ",text," : ",ord(text))
# Out:
# ASCII value / Unicode value of  $ :  36

# %%
# 12. Write a program to print the character from a given ASCII value using `chr()`.

text=int(input("Enter the ASCII value / Unicode value : "))
print("Character is ",text," : ",chr(text))
# Out:
# Character is  36  :  $

# %%
# 13. Write a program to reverse a string using slicing.

text="Gayatri"
# print(text[6:1]) it will not work
# when we use negative indexing it starts from -1 and ends at begging of the string so, step=-1 means move from backside
print(text[::-1])
# Out:
# irtayaG

# %% [markdown]
# # 22 April

# %%
# Q1. What will be the output of the following? Also predict whether it returns True or False.

pythonlanguage = "Python"
print(pythonlanguage.upper())
print(pythonlanguage.lower())
# Out:
# PYTHON
# python

# %%
# Q2. Check whether the string below contains only alphabets. Write the code and state why the result is True or False.

pythoncourse = "DataScience"
print(pythoncourse.isalpha())
# Out:
# True

# %%
# Q3. Predict the output of each print statement and explain the difference.

pythonusername = "Admin99"
print(pythonusername.isalpha())
print(pythonusername.isdigit())
print(pythonusername.isalnum())
# Out:
# False
# False
# True

# %%
# Q4. What will be the output? Justify your answer for each line.

pythonpin = "4872"
print(pythonpin.isdigit())  # yes True here ,because pythonpin variable contains digit only
pin2 = "48.72"
print(pin2.isdigit()) # False because isdigit() check digit from 0-9 only it will not work on numeric
# Out:
# True
# False

# %%
# Q5. Predict the output of both print statements and explain the behavior of islower().

pythonword1 = "hello world"
word2 = "Hello World"
print(pythonword1.islower()) # is lower is check whether the given string is in lowercase or not and gives output in bool format
print(word2.islower())
# Out:
# True
# False

# %%
# Q6. What will be printed? State when isupper() returns True vs False.

pythontag1 = "PYTHON"
tag2 = "PyTHON"
print(pythontag1.isupper()) # here isupper() returns True
print(tag2.isupper())        # here isupper() returns False
# Out:
# True
# False

# %%
# Q7. What is the output of the following? Also explain what startswith() checks.

email = "contact@gmail.com"
print(email.startswith("contact"))
print(email.startswith("gmail"))

#startswith() checks  the string is start with that letter or not
# Out:
# True
# False

# %%
# Q8. Predict the output. Then explain why the second print gives False.

filename = "report_2024.pdf"
print(filename.endswith(".pdf"))
print(filename.endswith(".docx")) # it gives false because the string is end with .pdf not .docx
# Out:
# True
# False

# %%
# Q9. What will find() return in each case? Write the output and explain.

#find() returns the starting index of that string in sentence if the string is present there , other wise if string is absent it will return -1

sentence = "Hello, welcome to python programming"
print(sentence.find("python")) 
print(sentence.find("Python"))
print(sentence.find("java"))
# Out:
# 18
# -1
# -1

# %%
# Q10. Use len(), min(), and max() on the string below and write what each one returns.

city = "Mumbai"
print(len(city)) # it returns length of the string
print(min(city)) # it returns which character of the string have minimum unicode value 
print(max(city)) # it returns which character of the string have maximum unicode value
# Out:
# 6
# M
# u

# %%
# Q11. Given the string below, use startswith() and endswith() together to check if it looks like a valid Python filename.

fname = "assignment1.py"
print(fname.startswith("assignment"))
print(fname.endswith(".py"))
# Out:
# True
# True

# %%
#Q12. Predict the output. What is the difference between isalpha() and isalnum()?

val1 = "Rupee100"
val2 = "Rupee"

print(val1.isalpha()) # it returns True if the string contains only alphabets
print(val1.isalnum()) # it returns True if the string contains both alphabets and digits
print(val2.isalpha())
print(val2.isalnum())
# Out:
# False
# True
# True
# True

# %%
#Q13. What index does find() return for 'india' in the string below? Verify using indexing.

phrase = "welcome to india"
idx = phrase.find("india")
print(idx)
print(phrase[idx:idx+5])
# Out:
# 11
# india

# %%
# Q14. What will be the output? Explain the role of len() as a built-in function vs a method.

product = "Laptop"
print(len(product)) #len() is a built in function it gives us length of the string
print(max(product))
print(min(product))

#built in function is work on many data type but methods of the strings are specific they only work on string

# %%
#Q15. Write code to check all of the following for the string below and predict each output.

data = "HelloWorld"
print(data.isalpha())               
print(data.islower())
print(data.isupper())
print(data.startswith("Hello"))
print(data.endswith("World"))
# Out:
# True
# False
# False
# True
# True

# %% [markdown]
# # 24 April

# %%
#Q1. What will be the output? Predict before running.

intro = "Hello, welcome to Python programming"
updated_intro = intro.replace("Python", "Java") 
print(updated_intro)    #Output : "Hello, welcome to Java programming"
# Out:
# Hello, welcome to Java programming

# %%
#Q2. What will be the output of both print statements? What does lstrip() remove?

raw_name = "   Amit Kumar   "
print(raw_name)      
stripped_left = raw_name.lstrip()  #lstrip() remove whitespaces from left side of the string
print(stripped_left)  # Output :" Amit Kumar"
# Out:
#    Amit Kumar
# Amit Kumar

# %%
#Q3. Predict the output. What does rstrip() keep and what does it remove?

padded_city = "   Pune   "
stripped_right = padded_city.rstrip() #restrip() keeps whitespaces from left side and remove it from right side
print(stripped_right) # Output :" Pune"
# Out:
#    Pune

# %%
#Q4. What will be the output? Explain the difference between strip() and lstrip().

user_input = "   Data Science   "
clean_input = user_input.strip() #strip() removes whitespaces from both side and lstrip() removes whitespaces from left side
print(clean_input) # Output :"Data Science"
# Out:
# Data Science

# %%
#Q5. Predict the output. What data type does split() return?

address = "Mumbai Pune Delhi Chennai"
city_list = address.split(" ") # split returns in list data type
print(city_list) # Output : ['Mumbai', 'Pune', 'Delhi', 'Chennai']
# Out:
# ['Mumbai', 'Pune', 'Delhi', 'Chennai']

# %%
#Q6. What will be the output? How many parts does partition() always return?

bio = "My name is Rajesh"
bio_parts = bio.partition("is") # partition() always return in 3 parts one is the part from where u want to partition and another two are from left side and right side of that partition word
print(bio_parts) # Output : "My name","is","Rajesh"
# Out:
# ('My name ', 'is', ' Rajesh')

# %%
#Q7. What will be the output of both print statements?

department = "COMPUTER SCIENCE"
dept_lower = department.lower()
print(dept_lower)  # Output : computer science

subject = "machine learning"
subject_upper = subject.upper()
print(subject_upper) #Output : MACHINE LEARNING
# Out:
# computer science
# MACHINE LEARNING

# %%
#Q8. Predict the output. What exactly does capitalize() do to the rest of the string?

college_name = "dr ambedkar institute of technology"
formatted_college = college_name.capitalize()
print(formatted_college) #Output : "Dr ambedkar institute of technology"
# Out:
# Dr ambedkar institute of technology

# %%
#Q9. What will be the output? How is title() different from capitalize()?

book_title = "the art of python programming"
proper_title = book_title.title() #title() convert the first letter of every word into uppercase and capitalize() convert the first letter in uppercase of first word only
print(proper_title) # Ouput : "The Art Of Python Programming"
# Out:
# The Art Of Python Programming

# %%
#Q10. Predict the output. What does swapcase() do to each character?

mixed_text = "pYTHON iS fUN"
swapped = mixed_text.swapcase()
print(swapped) #Output : "Python IS Fun"
# Out:
# Python Is Fun

# %%
#Q11. What will be the output of all three print statements?

marks = 95
percentage = 87.5
comp_num = 3+2j

marks_str = str(marks)
percentage_str = str(percentage)
comp_str = str(comp_num)

print(type(marks_str))   # all print statments are converted into string so Output : <class 'str'>
print(type(percentage_str))
print(type(comp_str))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
#Q12. What will be the output? What does chr() take as input?

letter1 = chr(66) # chr() takes unicode value as a input
print(letter1) # Output : B

letter2 = chr(98)
print(letter2) # Output : b
# Out:
# B
# b

# %%
#Q13. What will be the output? What does ord() take as input?

code1 = ord("Z") # ord() takes characters as a input 
print(code1) #Output : 90

code2 = ord("z")
print(code2) #Output : 122
# Out:
# 90
# 122

# %%
#Q14. Predict the output. What does join() use as the separator here?

skills = ["Python", "SQL", "Machine Learning", "Excel"]
skill_set = ", ".join(skills) # join() used , as a separator here
print(skill_set) #Output : Python, SQL, Machine Learning, Excel
# Out:
# Python, SQL, Machine Learning, Excel

# %%
#Q15. What will be the output of all three prints?

employee_data = "emp:Suresh:dept:HR"
updated_data = employee_data.replace("Suresh", "Ganesh")
print(updated_data) # Output : "emp:Ganesh:dept:HR"

split_data = employee_data.split(":")
print(split_data) # Output : 'emp', 'Suresh', 'dept', 'HR'

partition_data = employee_data.partition(":")
print(partition_data) # Output : 'emp', ':', 'Suresh:dept:HR'
# Out:
# emp:Ganesh:dept:HR
# ['emp', 'Suresh', 'dept', 'HR']
# ('emp', ':', 'Suresh:dept:HR')
